# %% [markdown]
# <font size ="8"> Filtering and Sorting Data</font>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

# %%
chipo = pd.read_csv(url, sep='\t')

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# <font size ="5">Step 4. How many products cost more than $10.00?</font>

# %%
products_over_10 = chipo.loc[chipo.item_price>=10.00]

# %%
#  data type change is needed here

# %%
chipo.item_price = chipo.item_price.apply(lambda x: float(x[1:-1]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 chipo.item_price = chipo.item_price.apply(lambda x: float(x[1:-1]))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# -> 4943     ).apply()
#
# ...

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %%
products_over_10 = chipo.loc[chipo.item_price>=10.00]

# %%
print("There are " + str(products_over_10.item_name.nunique()) + " products which price is over 10.00.")
# Out:
# There are 31 products which price is over 10.00.

# %% [markdown]
# <font size="5"> Step 5. What is the price of each item? </font>
# <font size="2"> print a data frame with only three columns item_name choice_description and product_price </font>

# %%
#prices = chipo.loc[:,["item_name","choice_description","item_price"]]
chipo['product_price'] = chipo['item_price'] / chipo['quantity']
prices = chipo.loc[:, ["item_name", "choice_description", "product_price"]].drop_duplicates()

# %%
print(prices.head(10))
# Out:
#                                item_name  \
# 0           Chips and Fresh Tomato Salsa
# 1                                   Izze
# 2                       Nantucket Nectar
# 3  Chips and Tomatillo-Green Chili Salsa
# 4                           Chicken Bowl
# 5                           Chicken Bowl
# 6                          Side of Chips
# 7                          Steak Burrito
# 8                       Steak Soft Tacos
# 9                          Steak Burrito
#
#                                   choice_description  product_price
# 0                                                NaN           2.39
# 1                                       [Clementine]           3.39
# 2                                            [Apple]           3.39
# 3                                                NaN           2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...           8.49
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...          10.98
# ...

# %% [markdown]
# <font size="5"> Step 6. Sort by the name of the item </font>

# %%
prices.sort_values(by='item_name', ascending=False)
# Out:
#               item_name                                 choice_description  \
# 3889  Veggie Soft Tacos  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...
# 781   Veggie Soft Tacos  [Fresh Tomato Salsa, [Black Beans, Cheese, Sou...
# 1699  Veggie Soft Tacos  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 738   Veggie Soft Tacos  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 2851  Veggie Soft Tacos  [Roasted Chili Corn Salsa (Medium), [Black Bea...
# ...                 ...                                                ...
# 341   6 Pack Soft Drink                                        [Diet Coke]
# 721   6 Pack Soft Drink                                           [Nestea]
# 3141  6 Pack Soft Drink                                         [Lemonade]
# 298   6 Pack Soft Drink                                           [Sprite]
# 357   6 Pack Soft Drink                                             [Coke]
#
#       product_price
# 3889           8.49
# 781            8.75
# ...

# %% [markdown]
# <font size="5">Step 7. What was the quantity of the most expensive item ordered?</font>

# %%
max_price = chipo.item_price.max()

# %%
most_exp = chipo[chipo.item_price == max_price]

# %%
print(most_exp)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price  product_price
# 3598       44.25           2.95

# %% [markdown]
# <font size="5">Step 8. How many times was a Veggie Salad Bowl ordered?</font>

# %%
veggie_salad_ordered_n_times = len(chipo[chipo.item_name == "Veggie Salad Bowl"])

# %%
print("The Veggie Salad Bowl was ordered " + str(veggie_salad_ordered_n_times) + " times")
# Out:
# The Veggie Salad Bowl was ordered 18 times

# %% [markdown]
# <font size="5">How many times did someone order more than one Canned Soda?</font>

# %%
mutiple_canned_sodas = chipo[(chipo.item_name == "Canned Soda") & (chipo.quantity > 1)]

# %%
print(len(mutiple_canned_sodas))
# Out:
# 20
