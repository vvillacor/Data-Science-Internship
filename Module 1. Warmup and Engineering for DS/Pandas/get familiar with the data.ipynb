# %% [markdown]
# <font size="14">PRACTICAL TASKS: PANDAS </font>

# %% [markdown]
# <font size="6">Ex2 - Getting and Knowing your Data </font>

# %% [markdown]
# <font size ="5">Step 1. Import the necessary libraries</font>

# %%
import pandas as pd

# %% [markdown]
# Step 2. Import the dataset

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %% [markdown]
# Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv(url, sep='\t')

# %% [markdown]
# <font size ="5">Step 4. See the first 10 entries</font>

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# <font size ="5">Step 5. What is the number of observations in the dataset?</font>

# %%
num_obs = len(chipo)
print(num_obs)
# Out:
# 4622

# %%
chipo.count()
# Out:
# order_id              4622
# quantity              4622
# item_name             4622
# choice_description    3376
# item_price            4622
# dtype: int64

# %% [markdown]
# <font size ="5">Step 6. What is the number of columns in the dataset?
# Step 7. Print the name of all the columns.</font>

# %%
print(chipo.columns)
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# There are five columns in the dataset

# %%
#CORRECTION
print(chipo.shape)
# Out:
# (4622, 5)

# %% [markdown]
# <font size ="5">Step 8. How is the dataset indexed?</font>

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# <font size ="5">Step 9. Which was the most-ordered item?</font>

# %%
most_o_item =chipo.groupby('item_name').sum().sort_values(['quantity'], ascending=False)

# %%
most_o_item.head(1)
# Out:
#               order_id  quantity  \
# item_name
# Chicken Bowl    713926       761
#
#                                              choice_description  \
# item_name
# Chicken Bowl  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#
#                                                      item_price
# item_name
# Chicken Bowl  $16.98 $10.98 $11.25 $8.75 $8.49 $11.25 $8.75 ...

# %% [markdown]
#  Step 10 For the most-ordered item, how many items were ordered?

# %%
761 items were ordered.

# %% [markdown]
# <font size ="5">Step 11. What was the most ordered item in the choice_description column?</font>

# %%
most_CD_O_item =chipo.groupby('choice_description').sum().sort_values(['quantity'], ascending=False)

# %%
most_CD_O_item.head(1)
# Out:
#                     order_id  quantity  \
# choice_description
# [Diet Coke]           123455       159
#
#                                                             item_name  \
# choice_description
# [Diet Coke]         Canned SodaCanned SodaCanned Soda6 Pack Soft D...
#
#                                                            item_price
# choice_description
# [Diet Coke]         $2.18 $1.09 $1.09 $6.49 $2.18 $1.25 $1.09 $6.4...

# %% [markdown]
# <font size ="5">Step 12. How many items were orderd in total?</font>

# %%
chipo.quantity.sum()
# Out:
# np.int64(4972)

# %% [markdown]
# <font size ="5">Step 13. Turn the item price into a float. Check the item price type </font>

# %%
chipo.item_price.dtype
# Out:
# dtype('O')

# %% [markdown]
# Step 13.b. Create a lambda function and change the type of item price

# %%
chipo.item_price = chipo.item_price.apply(lambda x: float(x[1:-1]))

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# <font size="5">Step 14. How much was the revenue for the period in the dataset? <font>

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
#revenue = (chipo['quantity'] * chipo['item_price']).sum()
revenue = chipo.item_price.sum()

# %%
print("The revenue was: $" + str(revenue))
# Out:
# The revenue was: $34500.16

# %% [markdown]
# <font size="5">Step 15. How many orders were made in the period? <font>

# %%
chipo.order_id.nunique()
# Out:
# 1834

# %% [markdown]
# <font size="5">Step 16. What is the average revenue amount per order? <font>

# %%
#revenue_per_order = chipo.order_id.nunique()/revenue 
revenue_per_order =

# %%
print(revenue_per_order)
# Out:
# 0.04674157211735244

# %% [markdown]
# <font size="5">Step 17. How many different items are sold? <font>

# %%
chipo.item_name.nunique()
# Out:
# 50
